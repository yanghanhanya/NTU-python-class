# %%
import requests
from pyquery import PyQuery as pq
from bs4 import BeautifulSoup as bs

# %%
response = requests.get("https://technews.tw/category/cutting-edge/ai/")

# %%
response.text
# Out:
# '<!DOCTYPE html>\r\n<!--[if IE 7]>\r\n<html class="ie ie7" lang="zh-TW">\r\n<![endif]-->\r\n<!--[if IE 8]>\r\n<html class="ie ie8" lang="zh-TW">\r\n<![endif]-->\r\n<!--[if !(IE 7) | !(IE 8)  ]><!-->\r\n<html lang="zh-TW">\r\n<!--<![endif]-->\r\n<head>\r\n<meta charset="UTF-8" />\r\n<!--<meta name="viewport" content="width=device-width" />-->\r\n<meta name="msvalidate.01" content="5DEC29CE8988D72A1C6791568D17E9F3" />\r\n<meta name="google-site-verification" content="Fb8JUo8FsCKBCR6sNHNW83sKPV3W1YRAbpmeWVK0OqA" />\r\n<meta name="tf" content="10.0.0.145" />\r\n\r\n<meta name="Title" content="AI 人工智慧 | TechNews 科技新報" />\r\n<meta name="Description" content="AI 人工智慧 " />\r\n<meta property="fb:pages" content="436202956432960" />\r\n\r\n<!--FB Author Start-->\r\n         <meta content=\'https://www.facebook.com/technewsinside/\' property=\'article:author\'/>     \r\n          \r\n<!--FB Author END-->\r\n\r\n<title>AI 人工智慧 | TechNews 科技新報</title>\r\n<link rel="profile" href="http://gmpg.org/x
# ...

# %%
doc = pq(response.text)
#for eachTitle in doc("table > tbody>tr>td> > a").items():

#doc("#side-menu a").text()
# Out:
# ''

# %%
html_doc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-8ff6b1816d33> in <module>()
# ----> 1 html_doc
#
# NameError: name 'html_doc' is not defined
