# %%
import pandas 
def scrap(date):
    dfs = pandas.read_html("https://rate.bot.com.tw/xrt/all/"+ date )
    return dfs[0]

# %%
type(dfs)
# Out:
# list

# %%
len(dfs)
# Out:
# 1

# %%
type(currency.iloc[:,0])
# Out:
# pandas.core.series.Series

# %%
currency = dfs[0]

# %%
pp = pandas.concat([currency.iloc[:,0],currency.iloc[:,4]],axis=1)

# %%
pp
# Out:
#                         幣別 Unnamed: 4_level_0
#         Unnamed: 0_level_1               本行賣出
# 0       美金 (USD)  美金 (USD)             29.625
# 1       港幣 (HKD)  港幣 (HKD)              3.813
# 2       英鎊 (GBP)  英鎊 (GBP)              40.44
# 3       澳幣 (AUD)  澳幣 (AUD)              23.24
# 4   加拿大幣 (CAD)  加拿大幣 (CAD)              23.74
# 5   新加坡幣 (SGD)  新加坡幣 (SGD)              22.35
# 6   瑞士法郎 (CHF)  瑞士法郎 (CHF)              30.54
# 7       日圓 (JPY)  日圓 (JPY)             0.2653
# 8     南非幣 (ZAR)  南非幣 (ZAR)               2.41
# 9     瑞典幣 (SEK)  瑞典幣 (SEK)               3.67
# 10      紐元 (NZD)  紐元 (NZD)              21.09
# 11      泰幣 (THB)  泰幣 (THB)             0.9387
# 12  菲國比索 (PHP)  菲國比索 (PHP)                  -
# 13    印尼幣 (IDR)  印尼幣 (IDR)                  -
# 14      歐元 (EUR)  歐元 (EUR)              35.81
# 15      韓元 (KRW)  韓元 (KRW)                  -
# 16    越南盾 (VND)  越南盾 (VND)                  -
# 17    馬來幣 (MYR)  馬來幣 (MYR)                  -
# ...

# %%
currency.iloc[:,[0,4]]
# Out:
#                         幣別 Unnamed: 4_level_0
#         Unnamed: 0_level_1               本行賣出
# 0       美金 (USD)  美金 (USD)             29.625
# 1       港幣 (HKD)  港幣 (HKD)              3.813
# 2       英鎊 (GBP)  英鎊 (GBP)              40.44
# 3       澳幣 (AUD)  澳幣 (AUD)              23.24
# 4   加拿大幣 (CAD)  加拿大幣 (CAD)              23.74
# 5   新加坡幣 (SGD)  新加坡幣 (SGD)              22.35
# 6   瑞士法郎 (CHF)  瑞士法郎 (CHF)              30.54
# 7       日圓 (JPY)  日圓 (JPY)             0.2653
# 8     南非幣 (ZAR)  南非幣 (ZAR)               2.41
# 9     瑞典幣 (SEK)  瑞典幣 (SEK)               3.67
# 10      紐元 (NZD)  紐元 (NZD)              21.09
# 11      泰幣 (THB)  泰幣 (THB)             0.9387
# 12  菲國比索 (PHP)  菲國比索 (PHP)                  -
# 13    印尼幣 (IDR)  印尼幣 (IDR)                  -
# 14      歐元 (EUR)  歐元 (EUR)              35.81
# 15      韓元 (KRW)  韓元 (KRW)                  -
# 16    越南盾 (VND)  越南盾 (VND)                  -
# 17    馬來幣 (MYR)  馬來幣 (MYR)                  -
# ...

# %%
dic={ "2018-01-02":["USD",100],
      "2018-01-04":["USD", 23 ]  
}

# %%
for i in dic.keys():
    df=scrap(i)

# %%
df
# Out:
#                         幣別     現金匯率 Unnamed: 2_level_0    即期匯率  \
#         Unnamed: 0_level_1     本行買入               本行賣出    本行買入
# 0       美金 (USD)  美金 (USD)    29.23             29.772   29.53
# 1       港幣 (HKD)  港幣 (HKD)    3.638              3.828   3.753
# 2       英鎊 (GBP)  英鎊 (GBP)    38.92              40.85   39.79
# 3       澳幣 (AUD)  澳幣 (AUD)    22.92              23.58   23.11
# 4   加拿大幣 (CAD)  加拿大幣 (CAD)    23.25              23.99   23.52
# 5   新加坡幣 (SGD)  新加坡幣 (SGD)    21.75              22.53   22.17
# 6   瑞士法郎 (CHF)  瑞士法郎 (CHF)    29.57              30.63    30.1
# 7       日圓 (JPY)  日圓 (JPY)   0.2543             0.2653  0.2607
# 8     南非幣 (ZAR)  南非幣 (ZAR)        -                  -    2.36
# 9     瑞典幣 (SEK)  瑞典幣 (SEK)     3.24               3.75    3.58
# 10      紐元 (NZD)  紐元 (NZD)    20.73              21.36   20.97
# 11      泰幣 (THB)  泰幣 (THB)   0.8137             0.9567  0.9022
# 12  菲國比索 (PHP)  菲國比索 (PHP)   0.5201             0.6531       -
# ...
